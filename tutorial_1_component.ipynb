# %%
from plot_publication import *
import numpy as np
import os

path_figure_dir = "figures"

# %% [markdown]
# # Observation vs Prediction

# %%
# plot
Fig = FigurePublication(1, 1)
fig, axes = Fig.fig, Fig.ax
ax: plt.Axes = axes

ax.clear()  # clear the current Axes state without closing it.

ax.set_box_aspect(1) # make a square box

# generate data for illustration
x = np.random.rand(100) * 2
y = x + np.random.rand(100)

# * draft plot x-y
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")

# * get maximum range of each ax
limits = [
    np.max([np.min([ax.get_xlim(), ax.get_ylim()]), 0]),  # min of both axes, but no smaller than 0
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]
# adjust limits of x and y
ax.set_xlim(limits)
ax.set_ylim(limits)

# * plot y=x according to the limits of x and y
ax.plot(limits, limits, "k-", alpha=0.8, zorder=0)

set_axis(ax, "x", 0, 3, 7)
set_axis(ax, "y", 0, 3, 7)
enable_minor_locator(ax)

ax.set_xlabel("Estimated discharge (%s)" % UnitTex.discharge("m", "s"))
ax.set_ylabel("Observed discharge (%s)" % UnitTex.discharge("m", "s"))

# * add statistic metrics
nse = 0.99 # r2(np.array(x), np.array(y))
loss = 0.1 # mse(np.array(x), np.array(y))
text_metric = "$\mathrm{MSE} = %.4f$\n$\mathrm{R^2} =%.4f$" % (loss, nse)

Fig.corner_annotate(ax, text_metric)

# fig.tight_layout()

# %% [markdown]
# # Figure index

# %%
Fig = FigurePublication(1, 3)
fig, axes = Fig.fig, Fig.ax

x = np.linspace(1, 10, 50)

ax = axes[0]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) - 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")
set_axis(ax, "x", 0, 12, 5)
# set_axis(ax, "y", 0, 3, 7)

ax = axes[1]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50)
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
set_axis(ax, "x", 0, 12, 5)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

ax = axes[2]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) + 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
set_axis(ax, "x", 0, 12, 5)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

# ! add figure index for each sub-figure
inch = 0.1 # inch
Fig.corner_annotate(axes[0], "(A)", pad=inch)
Fig.corner_annotate(axes[1], "(B)", pad=inch)
Fig.corner_annotate(axes[2], "(C)", pad=inch)

fig.tight_layout(w_pad=2)
# Out:
# C:\Users\ruozh\AppData\Local\Temp\ipykernel_21064\2136320265.py:37: UserWarning: The figure layout has changed to tight
#   fig.tight_layout(w_pad=2)

# %% [markdown]
# # Control **ticks** and axis **limits**

# %%
Fig = FigurePublication(1, 3)
fig, axes = Fig.fig, Fig.ax

x = np.linspace(1, 10, 50)

ax = axes[0]
ax.cla()  # clear the current Axes state without closing it.
ax.set_title("Default ticks")
y = x + np.random.rand(50) - 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")

ax = axes[1]
ax.cla()  # clear the current Axes state without closing it.
ax.set_title("Sparse ticks")
y = x + np.random.rand(50) - 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")

# ! control density of ticks
set_axis(ax, "x", 0, 12, num_ticks=7)
set_axis(ax, "y", -2, 8, num_ticks=6)

ax = axes[2]
ax.cla()  # clear the current Axes state without closing it.
ax.set_title("Dense ticks")
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")

# ! control density of ticks
set_axis(ax, "x", 0, 12, num_ticks=13)
set_axis(ax, "y", -2, 8, num_ticks=11)
enable_minor_locator(ax, n=6)

# %% [markdown]
# # Shared y-axis
#
# ## Keep y-ticks & Drop y-ticks

# %%
Fig = FigurePublication(1, 3)
fig, axes = Fig.fig, Fig.ax

x = np.linspace(1, 10, 50)

ax = axes[0]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) - 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

ax = axes[1]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50)
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

ax = axes[2]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) + 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

# ! find and set proper ylim for all
set_equal_ylim(axes)

inch = 0.03
Fig.corner_annotate(axes[0], "(A)", pad=inch)
Fig.corner_annotate(axes[1], "(B)", pad=inch)
Fig.corner_annotate(axes[2], "(C)", pad=inch)


# fig.tight_layout(w_pad=2)

# %% [markdown]
# # Legend for all sub-figures

# %%
Fig = FigurePublication(1, 3)
fig, axes = Fig.fig, Fig.ax

x = np.linspace(1, 10, 50)

ax = axes[0]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) - 3
line1, = ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

ax = axes[1]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50)
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

ax = axes[2]
ax.cla()  # clear the current Axes state without closing it.
y = x + np.random.rand(50) + 3
ax.plot(x, y, "g", alpha=0.5, linestyle="", marker=".", markerfacecolor="none")
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

set_equal_ylim(axes)
axes[1].get_yaxis().set_visible(False)
axes[2].get_yaxis().set_visible(False)

inch = 0.03
Fig.corner_annotate(axes[0], "(A)", pad=inch)
Fig.corner_annotate(axes[1], "(B)", pad=inch)
Fig.corner_annotate(axes[2], "(C)", pad=inch)


# ! add a legend for all plot
# enable_figure_legend(fig, [line1], ["Label 1"], height_ratio=0.62)

for ax in axes.flatten():  # convert to 1d array
    ax.set_box_aspect(None)

# Fig.stretch_figure_height(0.17) # with y label
Fig.stretch_figure_height(0.3)


enable_figure_legend(fig, [line1], ["Label 1"], height_ratio=1.0, placeholder_size=0.4)

fig.tight_layout(pad=0.5)
# Out:
# C:\Users\ruozh\AppData\Local\Temp\ipykernel_21064\3362379606.py:49: UserWarning: The figure layout has changed to tight
#   fig.tight_layout(pad=0.5)

# %% [markdown]
# # Leave space for figure index

# %%
Fig = FigurePublication(1, 2)
fig, axes = Fig.fig, Fig.ax

x = np.linspace(1, 10, 50)
for ax in axes:
    ax.cla()  # clear the current Axes state without closing it.
    y = np.sin(x + np.pi / 4)
    ax.plot(x, y, label='XXX')
    ax.set_xlabel("X label")
    ax.set_ylabel("Y label")
    enable_axes_legend(ax)

# ! leave space at top left corner for sub-figure index
more_space(axes[1], direction="left", ratio=0.1)

# add index for each sub-figure
Fig.corner_annotate(axes[0], "(A)")
Fig.corner_annotate(axes[1], "(B)")

# %% [markdown]
# # Color bar
#
# # Method 1

# %%
Fig = FigurePublication(1, 1)
fig, ax = Fig.fig, Fig.ax

np.random.seed(999)
matrix = np.random.rand(3,3)

# control range of color
vmin = np.min(matrix)
vmax = np.max(matrix)
dv = vmax - vmin
vmin -= 0.3 * dv
vmax += 0.01 * dv

# https://matplotlib.org/stable/gallery/images_contours_and_fields/interpolation_methods.html
pos = ax.imshow(matrix, interpolation="bilinear", cmap=matplotlib.colormaps["Reds"], vmin=vmin, vmax=vmax)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")

# * set color bar
# https://matplotlib.org/stable/gallery/color/colorbar_basics.html
# clb = fig.colorbar(pos, ax=ax, location="right", fraction=1, pad=0.08)
clb = fig.colorbar(pos, ax=ax, location="right", fraction=0.05, pad=0.08)

tick_locator = MaxNLocator(nbins=9)
clb.locator = tick_locator
clb.update_ticks()

clb.ax.set_title("Title")
clb.set_label("Label")

# %% [markdown]
# ## Method 2
#
# Looks better but more complicated.

# %%
Fig = FigurePublication(1, 1)
fig, axes = Fig.fig, Fig.ax

fig.clear()


w_ratios = [20, 1]
h_ratios = [1]

row_count = 1
col_count = 2
# * specify grids for creating axes with different size
gs = fig.add_gridspec(nrows=row_count, ncols=col_count, width_ratios=w_ratios, height_ratios=h_ratios)

# * create each axes
ax1 = fig.add_subplot(gs[0, 0])
ax1.set_box_aspect(1)  # image usually displayed in square
ax1.set_xlabel("X label")
ax1.set_ylabel("Y label")

ax_cb = fig.add_subplot(gs[0, 1])

# set proper figure width, if width is too small, the color bar will much longer than the sub-figure created by imshow(),
# because the sub-figure will be compressed to achieve aspect ratio equal 1.0
Fig.stretch_figure_width(1.05)

# %%
np.random.seed(999)
matrix = np.random.rand(3, 3)

# control range of color
vmin = np.min(matrix)
vmax = np.max(matrix)
dv = vmax - vmin
vmin -= 0.3 * dv
vmax += 0.01 * dv

ax = ax1
# https://matplotlib.org/stable/gallery/images_contours_and_fields/interpolation_methods.html
img = ax.imshow(matrix, interpolation="bilinear", cmap=matplotlib.colormaps["Reds"], vmin=vmin, vmax=vmax)


# * set color bar
# https://matplotlib.org/stable/gallery/color/colorbar_basics.html

clb = fig.colorbar(img, cax=ax_cb, pad=0.8)
# Note: no need to manually adjust fraction and pad

clb.locator = MaxNLocator(nbins=11)
# clb.update_ticks()

clb.ax.set_title("Title")
clb.set_label("Label")
fig
